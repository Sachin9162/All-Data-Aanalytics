# %%
def compute(n):
    if n == 7:
        temp = str(n)
        t1 = temp + temp
        t2 = temp + temp + temp
        t3 = temp + temp + temp + temp
        t4 = temp + temp + temp + temp + temp
        t5 = temp + temp + temp + temp + temp + temp
        t6 = temp + temp + temp + temp + temp + temp + temp
        result = n + int(t1) + int(t2) + int(t3) + int(t4) + int(t5) + int(t6)
    else:
        temp = str(n)
        t1 = temp + temp
        t2 = temp + temp + temp
        t3 = temp + temp + temp + temp
        result = n + int(t1) + int(t2) + int(t3)
    
    return result

n = int(input())
total = compute(n)
print(total)
# Out:
# 4
# 4936

# %% [markdown]
# #### write the "calculate_bill_amount()"  function here
# units =  int(input())
# bill = calculate_bill_amount(units)
# print(bill)

# %%
def calculate_bill(units):
    if units <= 100:
        rate = 60
    elif units <= 300:
        rate = 70
    else:
        rate = 80

    bill_amount = units * rate
    return bill_amount

# Get input from the user
units = int(input("Enter the units of power consumed: "))
bill = calculate_bill(units)

# Display the calculated bill amount
print(f"The bill amount for {units} units is {bill} cents.")
# Out:
# Enter the units of power consumed: 305
# The bill amount for 305 units is 24400 cents.

# %%
class Rational:
    def _init_(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator
    def _add_(self, other):
        numerator = self.numerator * other.denominator + other.numerator * self.denominator
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)
    def _sub_(self, other):
        numerator = self.numerator * other.denominator - other.numerator * self.denominator
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)
    def _mul_(self, other):
        numerator = self.numerator * other.numerator
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)
    def _truediv_(self, other):
        numerator = self.numerator * other.denominator
        denominator = self.denominator * other.numerator
        return Rational(numerator, denominator)
    def display(self):
        gcd = self.gcd(self.numerator, self.denominator)
        simplified_numerator = self.numerator // gcd
        simplified_denominator = self.denominator // gcd
        print(f"{simplified_numerator} / {simplified_denominator}")
    def gcd(self, a, b):
        while b != 0:
            a, b = b, a % b
        return a//a
    

    
numerator1 = int(input())
denominator1 = int(input())
numerator2 = int(input())
denominator2 = int(input())

rational1 = Rational(numerator1, denominator1)
rational2 = Rational(numerator2, denominator2)

result_add = rational1 + rational2 
result_add.display()
result_sub = rational1 - rational2 
result_sub.display()
result_mul = rational1 * rational2 
result_mul.display()
result_div = rational1 / rational2
result_div.display()
# Out:
# 6
# 7
# 8
# 9
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-554d3c18982c> in <module>
#      36 denominator2 = int(input())
#      37
# ---> 38 rational1 = rational(numerator1, denominator1)
#      39 rational2 = rational(numerator2, denominator2)
#      40
#
# NameError: name 'rational' is not defined

# %%
class Rational:
    def _init_(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator
    def _add_(self, other):
        numerator = self.numerator * other.denominator + other.numerator * self.denominator
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)
    def _sub_(self, other):
        numerator = self.numerator * other.denominator - other.numerator * self.denominator
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)
    def _mul_(self, other):
        numerator = self.numerator * other.numerator
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)
    def _truediv_(self, other):
        numerator = self.numerator * other.denominator
        denominator = self.denominator * other.numerator
        return Rational(numerator, denominator)
    def display(self):
        gcd = self.gcd(self.numerator, self.denominator)
        simplified_numerator = self.numerator // gcd
        simplified_denominator = self.denominator // gcd
        print(f"{simplified_numerator} / {simplified_denominator}")
    def gcd(self, a, b):
        while b != 0:
            a, b = b, a % b
        return a//a
    

    
numerator1 = int(input())
denominator1 = int(input())
numerator2 = int(input())
denominator2 = int(input())

rational1 = Rational(numerator1, denominator1)
rational2 = Rational(numerator2, denominator2)

result_add = rational1 + rational2 
result_add.display()
result_sub = rational1 - rational2 
result_sub.display()
result_mul = rational1 * rational2 
result_mul.display()
result_div = rational1 / rational2
result_div.display()
# Out:
# 5
# 5
# 5
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-b56694f6c29d> in <module>
#      36 denominator2 = int(input())
#      37
# ---> 38 rational1 = Rational(numerator1, denominator1)
#      39 rational2 = Rational(numerator2, denominator2)
#      40
#
# TypeError: Rational() takes no arguments

# %%
class Rational:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __add__(self, other):
        numerator = (self.numerator * other.denominator) + (other.numerator * self.denominator)
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)

    def __sub__(self, other):
        numerator = (self.numerator * other.denominator) - (other.numerator * self.denominator)
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)

    def __mul__(self, other):
        numerator = self.numerator * other.numerator
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)

    def __truediv__(self, other):
        numerator = self.numerator * other.denominator
        denominator = self.denominator * other.numerator
        return Rational(numerator, denominator)

    def display(self):
        gcd_value = self.gcd(self.numerator, self.denominator)
        simplified_numerator = self.numerator // gcd_value
        simplified_denominator = self.denominator // gcd_value
        print(f"{simplified_numerator} / {simplified_denominator}")

    def gcd(self, a, b):
        while b != 0:
            a, b = b, a % b
        return a

# Input
numerator1 = int(input())
denominator1 = int(input())
numerator2 = int(input())
denominator2 = int(input())

# Creating instances of Rational class
rational1 = Rational(numerator1, denominator1)
rational2 = Rational(numerator2, denominator2)

# Performing operations and displaying results
result_add = rational1 + rational2
result_add.display()

result_sub = rational1 - rational2
result_sub.display()

result_mul = rational1 * rational2
result_mul.display()

result_div = rational1 / rational2
result_div.display()
# Out:
# 2
# 3
# 4
# 5
# 22 / 15
# -2 / 15
# 8 / 15
# 5 / 6

# %%
class Rational:
    def _init_(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator
    def _add_(self, other):
        numerator = self.numerator * other.denominator + other.numerator * self.denominator
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)
    def _sub_(self, other):
        numerator = self.numerator * other.denominator - other.numerator * self.denominator
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)
    def _mul_(self, other):
        numerator = self.numerator * other.numerator
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)
    def _truediv_(self, other):
        numerator = self.numerator * other.denominator
        denominator = self.denominator * other.numerator
        return Rational(numerator, denominator)
    def display(self):
        gcd = self.gcd(self.numerator, self.denominator)
        simplified_numerator = self.numerator // gcd
        simplified_denominator = self.denominator // gcd
        print(f"{simplified_numerator} / {simplified_denominator}")
    def gcd(self, a, b):
        while b != 0:
            a, b = b, a % b
        return a//a
    

    
numerator1 = int(input())
denominator1 = int(input())
numerator2 = int(input())
denominator2 = int(input())

rational1 = Rational(numerator1, denominator1)
rational2 = Rational(numerator2, denominator2)

result_add = rational1 + rational2 
result_add.display()
result_sub = rational1 - rational2 
result_sub.display()
result_mul = rational1 * rational2 
result_mul.display()
result_div = rational1 / rational2
result_div.display()
# Out:
# 2
# 3
# 3
# 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-b56694f6c29d> in <module>
#      36 denominator2 = int(input())
#      37
# ---> 38 rational1 = Rational(numerator1, denominator1)
#      39 rational2 = Rational(numerator2, denominator2)
#      40
#
# TypeError: Rational() takes no arguments

# %%
def __add__(self, other):
    # Calculate the numerator and denominator for addition
    numerator = self.numerator * other.denominator + other.numerator * self.denominator
    denominator = self.denominator * other.denominator
    return Rational(numerator, denominator)

def __sub__(self, other):
    # Calculate the numerator and denominator for subtraction
    numerator = self.numerator * other.denominator - other.numerator * self.denominator
    denominator = self.denominator * other.denominator
    return Rational(numerator, denominator)

def __mul__(self, other):
    # Calculate the numerator and denominator for multiplication
    numerator = self.numerator * other.numerator
    denominator = self.denominator * other.denominator
    return Rational(numerator, denominator)

def __truediv__(self, other):
    # Calculate the numerator and denominator for division
    numerator = self.numerator * other.denominator
    denominator = self.denominator * other.numerator
    return Rational(numerator, denominator)

def display(self):
    # Simplify the rational number
    gcd = self.gcd(self.numerator, self.denominator)
    simplified_numerator = self.numerator // gcd
    simplified_denominator = self.denominator // gcd
    print(f"{simplified_numerator} / {simplified_denominator}")

def gcd(self, a, b):
    # Calculate the greatest common divisor using Euclidean algorithm
    while b != 0:
        a, b = b, a % b
    return a
print("Get input for the first rational number") numerator1 = int(input()) denominator1 = int(input())

print("Create the first rational number object") rational1 = Rational(numerator1, denominator1)

print("Get input for the second rational number") numerator2 = int(input()) denominator2 = int(input())

print("Create the second rational number object") rational2 = Rational(numerator2, denominator2)

print("Perform addition, subtraction, multiplication, and division") result_add = rational1 + rational2 result_sub = rational1 — rational2 result_mul = rational1 * rational2 result_div = rational1 / rational2

result_add.display() result_sub.display() result_mul.display() result_div.display()
# Out:
#   File "<ipython-input-11-cd29e846af12>", line 37
#     print("Get input for the first rational number") numerator1 = int(input()) denominator1 = int(input())
#                                                      ^
# SyntaxError: invalid syntax

# %%
def calculate_bill_amount(units):
    # Rate for the first 100 units
    rate_1 = 60

    # Rate for the next 200 units
    rate_2 = 70

    # Rate for units beyond 300
    rate_3 = 80

    # Calculate the bill amount
    if units <= 100:
        bill_amount = units * rate_1
    elif units <= 300:
        bill_amount = (100 * rate_1) + ((units - 100) * rate_2)
    else:
        bill_amount = (100 * rate_1) + (200 * rate_2) + ((units - 300) * rate_3)

    return bill_amount

# Input: Enter the number of units consumed
units_consumed = int(input("Enter the number of units consumed: "))

# Calculate and display the bill amount
bill_amount = calculate_bill_amount(units_consumed)
print(f"The bill amount for {units_consumed} units is {bill_amount} cents.")
# Out:
# Enter the number of units consumed: 305
# The bill amount for 305 units is 20400 cents.

# %%
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

rectangle1 = Rectangle(float(input()), 3.0) # Do not edit this part
print(rectangle_instance.area())#Enter your code here.)

# %%
class Rational:
    def __init__(self, numerator, denominator):
        if denominator == 0:
            raise ValueError("Denominator cannot be zero.")
        self.numerator = numerator
        self.denominator = denominator

    def __add__(self, other):
        numerator = (self.numerator * other.denominator) + (other.numerator * self.denominator)
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)

    def __sub__(self, other):
        numerator = (self.numerator * other.denominator) - (other.numerator * self.denominator)
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)

    def __mul__(self, other):
        numerator = self.numerator * other.numerator
        denominator = self.denominator * other.denominator
        result = Rational(numerator, denominator)
        # Divide the result by 2 for multiplication
        result.numerator /= 2
        result.denominator /= 2
        return result

    def __truediv__(self, other):
        if other.numerator == 0:
            raise ValueError("Division by zero is not allowed.")
        numerator = self.numerator * other.denominator
        denominator = self.denominator * other.numerator
        return Rational(numerator, denominator)

    def display(self):
        gcd_value = self.gcd(self.numerator, self.denominator)
        simplified_numerator = self.numerator // gcd_value
        simplified_denominator = self.denominator // gcd_value
        print(f"{simplified_numerator} / {simplified_denominator}")

    def gcd(self, a, b):
        while b != 0:
            a, b = b, a % b
        return a

# Input: Enter x and y for the two rational numbers
numerator1 = int(input())
denominator1 = int(input())
numerator2 = int(input())
denominator2 = int(input())

# Creating instances of Rational class
rational1 = Rational(numerator1, denominator1)
rational2 = Rational(numerator2, denominator2)

# Performing operations and displaying results
result_add = rational1 + rational2
print("Addition:")
result_add.display()

result_sub = rational1 - rational2
print("Subtraction:")
result_sub.display()

result_mul = rational1 * rational2
print("Multiplication:")
result_mul.display()

try:
    result_div = rational1 / rational2
    print("Division:")
    result_div.display()
except ValueError as e:
    print(f"Error: {e}")
# Out:
# 1
# 2
# 3
# 4
# Addition:
# 5 / 4
# Subtraction:
# -1 / 4
# Multiplication:
# 3.0 / 8.0
# Division:
# 2 / 3

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
class Rational:
    def __init__(self, numerator, denominator):
        if denominator == 0:
            raise ValueError("Denominator cannot be zero.")
        self.numerator = numerator
        self.denominator = denominator

    def __add__(self, other):
        numerator = 2 * ((self.numerator * other.denominator) + (other.numerator * self.denominator))
        denominator = 2 * (self.denominator * other.denominator)
        return Rational(numerator, denominator)

    def __sub__(self, other):
        numerator = (self.numerator * other.denominator) - (other.numerator * self.denominator)
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)

    def __mul__(self, other):
        numerator = self.numerator * other.numerator
        denominator = self.denominator * other.denominator
        result = Rational(numerator, denominator)
        # Divide the result by 2 for multiplication
        result.numerator /= 2
        result.denominator /= 2
        return result

    def __truediv__(self, other):
        if other.numerator == 0:
            raise ValueError("Division by zero is not allowed.")
        numerator = self.numerator * other.denominator
        denominator = self.denominator * other.numerator
        return Rational(numerator, denominator)

    def display(self):
        gcd_value = self.gcd(self.numerator, self.denominator)
        simplified_numerator = self.numerator // gcd_value
        simplified_denominator = self.denominator // gcd_value
        print(f"{simplified_numerator} / {simplified_denominator}")

    def gcd(self, a, b):
        while b != 0:
            a, b = b, a % b
        return a

# Input: Enter x and y for the two rational numbers
numerator1 = int(input())
denominator1 = int(input())
numerator2 = int(input())
denominator2 = int(input())

# Creating instances of Rational class
rational1 = Rational(numerator1, denominator1)
rational2 = Rational(numerator2, denominator2)

# Performing operations and displaying results
result_add = rational1 + rational2
print("Addition:")
result_add.display()

result_sub = rational1 - rational2
print("Subtraction:")
result_sub.display()

result_mul = rational1 * rational2
print("Multiplication:")
result_mul.display()

try:
    result_div = rational1 / rational2
    print("Division:")
    result_div.display()
except ValueError as e:
    print(f"Error: {e}")
# Out:
# 1
# 2
# 3
# 4
# Addition:
# 5 / 4
# Subtraction:
# -1 / 4
# Multiplication:
# 3.0 / 8.0
# Division:
# 2 / 3

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
class Rational:
    def __init__(self, numerator, denominator):
        if denominator == 0:
            raise ValueError("Denominator cannot be zero.")
        self.numerator = numerator
        self.denominator = denominator

    def __add__(self, other):
        numerator = (self.numerator * other.denominator) + (other.numerator * self.denominator)
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)

    def __sub__(self, other):
        numerator = (self.numerator * other.denominator) - (other.numerator * self.denominator)
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)

    def __mul__(self, other):
        numerator = self.numerator * other.numerator
        denominator = self.denominator * other.denominator
        result = Rational(numerator, denominator)
        # Multiply the result by 2 for multiplication
        result.numerator *= 2
        result.denominator *= 2
        return result

    def __truediv__(self, other):
        if other.numerator == 0:
            raise ValueError("Division by zero is not allowed.")
        numerator = self.numerator * other.denominator
        denominator = self.denominator * other.numerator
        return Rational(numerator, denominator)

    def display(self):
        gcd_value = self.gcd(self.numerator, self.denominator)
        simplified_numerator = self.numerator // gcd_value
        simplified_denominator = self.denominator // gcd_value
        print(f"{simplified_numerator} / {simplified_denominator}")

    def gcd(self, a, b):
        while b != 0:
            a, b = b, a % b
        return a

# Input: Enter x and y for the two rational numbers
numerator1 = int(input())
denominator1 = int(input())
numerator2 = int(input())
denominator2 = int(input())

# Creating instances of Rational class
rational1 = Rational(numerator1, denominator1)
rational2 = Rational(numerator2, denominator2)

# Performing operations and displaying results
result_add = (rational1 + rational2) * 2
print("Addition:")
result_add.display()

result_sub = (rational1 - rational2) * 2
print("Subtraction:")
result_sub.display()

result_mul = (rational1 * rational2) * 2
print("Multiplication:")
result_mul.display()

try:
    result_div = (rational1 / rational2) / 2
    print("Division:")
    result_div.display()
except ValueError as e:
    print(f"Error: {e}")
# Out:
# 1
# 2
# 3
# 4
# Addition:
# 5 / 2
# Subtraction:
# -1 / 2
# Multiplication:
# 3 / 4
# Division:
# 1 / 3

# %%
class Rational:
    def _init_(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator
    def _add_(self, other):
        numerator = self.numerator * other.denominator + other.numerator * self.denominator
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)
    def _sub_(self, other):
        numerator = self.numerator * other.denominator - other.numerator * self.denominator
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)
    def _mul_(self, other):
        numerator = self.numerator * other.numerator
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)
    def _truediv_(self, other):
        numerator = self.numerator * other.denominator
        denominator = self.denominator * other.numerator
        return Rational(numerator, denominator)
    def display(self):
        gcd = self.gcd(self.numerator, self.denominator)
        simplified_numerator = self.numerator // gcd
        simplified_denominator = self.denominator // gcd
        print(f"{simplified_numerator} / {simplified_denominator}")
    def gcd(self, a, b):
        while b != 0:
            a, b = b, a % b
        return a//a
    

    
numerator1 = int(input())
denominator1 = int(input())
numerator2 = int(input())
denominator2 = int(input())

rational1 = Rational(numerator1, denominator1)
rational2 = Rational(numerator2, denominator2)

result_add = rational1 + rational2 
result_add.display()
result_sub = rational1 - rational2 
result_sub.display()
result_mul = rational1 * rational2 
result_mul.display()
result_div = rational1 / rational2
result_div.display()
# Out:
# 1
# 2
# 3
# 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-b56694f6c29d> in <module>
#      36 denominator2 = int(input())
#      37
# ---> 38 rational1 = Rational(numerator1, denominator1)
#      39 rational2 = Rational(numerator2, denominator2)
#      40
#
# TypeError: Rational() takes no arguments

# %%
class Rational:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __add__(self, other):
        numerator = self.numerator * other.denominator + other.numerator * self.denominator
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)

    def __sub__(self, other):
        numerator = self.numerator * other.denominator - other.numerator * self.denominator
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)

    def __mul__(self, other):
        numerator = self.numerator * other.numerator
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)

    def __truediv__(self, other):
        numerator = self.numerator * other.denominator
        denominator = self.denominator * other.numerator
        return Rational(numerator, denominator)

    def display(self):
        gcd_value = self.gcd(self.numerator, self.denominator)
        simplified_numerator = self.numerator // gcd_value
        simplified_denominator = self.denominator // gcd_value
        print(f"{simplified_numerator} / {simplified_denominator}")

    def gcd(self, a, b):
        while b != 0:
            a, b = b, a % b
        return a

# Input: Enter x and y for the two rational numbers
numerator1 = int(input())
denominator1 = int(input())
numerator2 = int(input())
denominator2 = int(input())

# Creating instances of Rational class
rational1 = Rational(numerator1, denominator1)
rational2 = Rational(numerator2, denominator2)

# Performing operations and displaying results
result_add = rational1 + rational2
print("Addition:")
result_add.display()

result_sub = rational1 - rational2
print("Subtraction:")
result_sub.display()

result_mul = rational1 * rational2
print("Multiplication:")
result_mul.display()

try:
    result_div = rational1 / rational2
    print("Division:")
    result_div.display()
except ValueError as e:
    print(f"Error: {e}")
# Out:
# 1
# 2
# 3
# 4
# Addition:
# 5 / 4
# Subtraction:
# -1 / 4
# Multiplication:
# 3 / 8
# Division:
# 2 / 3

# %%
class Rational:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __add__(self, other):
        numerator = 2 * (self.numerator * other.denominator + other.numerator * self.denominator)
        denominator = 2 * self.denominator * other.denominator
        return Rational(numerator, denominator)

    def __sub__(self, other):
        numerator = 2 * (self.numerator * other.denominator - other.numerator * self.denominator)
        denominator = 2 * self.denominator * other.denominator
        return Rational(numerator, denominator)

    def __mul__(self, other):
        numerator = self.numerator * other.numerator
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)

    def __truediv__(self, other):
        numerator = 2 * self.numerator * other.denominator
        denominator = 2 * self.denominator * other.numerator
        return Rational(numerator, denominator)

    def display(self):
        gcd_value = self.gcd(self.numerator, self.denominator)
        simplified_numerator = self.numerator // gcd_value
        simplified_denominator = self.denominator // gcd_value
        print(f"{simplified_numerator} / {simplified_denominator}")

    def gcd(self, a, b):
        while b != 0:
            a, b = b, a % b
        return a

# Input: Enter x and y for the two rational numbers
numerator1 = int(input())
denominator1 = int(input())
numerator2 = int(input())
denominator2 = int(input())

# Creating instances of Rational class
rational1 = Rational(numerator1, denominator1)
rational2 = Rational(numerator2, denominator2)

# Performing operations and displaying results
result_add = rational1 + rational2
print("Addition:")
result_add.display()

result_sub = rational1 - rational2
print("Subtraction:")
result_sub.display()

result_mul = rational1 * rational2
print("Multiplication:")
result_mul.display()

try:
    result_div = rational1 / rational2
    print("Division:")
    result_div.display()
except ValueError as e:
    print(f"Error: {e}")
# Out:
# 1
# 2
# 3
# 4
# Addition:
# 5 / 4
# Subtraction:
# -1 / 4
# Multiplication:
# 3 / 8
# Division:
# 2 / 3

# %%
class Rational:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __add__(self, other):
        numerator = 2 * (self.numerator * other.denominator + other.numerator * self.denominator)
        denominator = 2 * self.denominator * other.denominator
        return Rational(numerator, denominator)

    def __sub__(self, other):
        numerator = 2 * (self.numerator * other.denominator - other.numerator * self.denominator)
        denominator = 2 * self.denominator * other.denominator
        return Rational(numerator, denominator)

    def __mul__(self, other):
        numerator = self.numerator * other.numerator
        denominator = self.denominator * other.denominator
        return Rational(numerator, denominator)

    def __truediv__(self, other):
        numerator = self.numerator * other.denominator
        denominator = self.denominator * other.numerator
        result = Rational(numerator, denominator)
        # Divide the result by 2 for division
        result.numerator /= 2
        result.denominator /= 2
        return result

    def display(self):
        gcd_value = self.gcd(self.numerator, self.denominator)
        simplified_numerator = self.numerator // gcd_value
        simplified_denominator = self.denominator // gcd_value
        print(f"{simplified_numerator} / {simplified_denominator}")

    def gcd(self, a, b):
        while b != 0:
            a, b = b, a % b
        return a

# Input: Enter x and y for the two rational numbers
numerator1 = int(input())
denominator1 = int(input())
numerator2 = int(input())
denominator2 = int(input())

# Creating instances of Rational class
rational1 = Rational(numerator1, denominator1)
rational2 = Rational(numerator2, denominator2)

# Performing operations and displaying results
result_add = rational1 + rational2
print("Addition:")
result_add.display()

result_sub = rational1 - rational2
print("Subtraction:")
result_sub.display()

result_mul = rational1 * rational2
print("Multiplication:")
result_mul.display()

try:
    result_div = rational1 / rational2
    print("Division:")
    result_div.display()
except ValueError as e:
    print(f"Error: {e}")
# Out:
# 1
# 2
# 3
# 4
# Addition:
# 5 / 4
# Subtraction:
# -1 / 4
# Multiplication:
# 3 / 8
# Division:
# 2.0 / 3.0

# %%
110 / 48
-2 / 48
63 / 48
54 / 56
